# %%
conn = psycopg2.connect("dbname=user43 user=user43 password=m5q3x8tpc7vn host=2.nntc.nnov.ru port=5402")
video_path = 'Модуль А/fallback2.mp4'

# %%
import cv2
import psycopg2
import time
import numpy as np
from ultralytics import YOLO
from datetime import datetime

# --- КОНФИГУРАЦИЯ ---
VIDEO_PATH = 'Модуль А/fallback2.mp4'
DB_URL = "dbname=user43 user=user43 password=m5q3x8tpc7vn host=2.nntc.nnov.ru port=5402"

# Линии для расчета скорости и калибровки (в пикселях)
LINE_1_Y = 350 
LINE_2_Y = 550  
REAL_DIST_M = 15.0 # Реальное расстояние между линиями в метрах
PIXELS_PER_METER = abs(LINE_2_Y - LINE_1_Y) / REAL_DIST_M

# Параметры сближений
CRITICAL_DIST_M = 3.5 # Порог срабатывания триггера в метрах
INCIDENT_COOLDOWN = 2 # Пауза в секундах перед повторной фиксацией той же пары

# --- ИНИЦИАЛИЗАЦИЯ ---
model = YOLO('yolo12s.pt')
cap = cv2.VideoCapture(VIDEO_PATH)
conn = psycopg2.connect(DB_URL)
conn.autocommit = True
cursor = conn.cursor()

entry_times = {} 
processed_ids = set()
last_incident_time = {} # Для предотвращения спама в БД {(id1, id2): timestamp}

print("🚀 Система запущена. Детекция сближений активна.")

try:
    while cap.isOpened():
        success, frame = cap.read()
        if not success: break
        
        now_ts = time.time()
        now_dt = datetime.now()
        
        # Трекинг объектов
        results = model.track(frame, persist=True, verbose=False, classes=[2, 3, 5, 7])
        annotated_frame = results[0].plot()

        if results[0].boxes.id is not None:
            # Преобразуем в обычные числа для SQL
            boxes = results[0].boxes.xyxy.cpu().numpy().astype(float)
            ids = results[0].boxes.id.cpu().numpy().astype(int)
            clss = results[0].boxes.cls.cpu().numpy().astype(int)
            
            active_objects = []

            for i in range(len(ids)):
                x1, y1, x2, y2 = boxes[i]
                t_id = int(ids[i])
                cx, cy = (x1 + x2) / 2, (y1 + y2) / 2
                active_objects.append({'id': t_id, 'cx': cx, 'cy': cy, 'name': model.names[clss[i]]})

                # Фиксация скорости (запись в full_tracking_data)
                if abs(cy - LINE_1_Y) < 30 and t_id not in entry_times:
                    entry_times[t_id] = now_ts
                
                if cy > LINE_2_Y and t_id in entry_times and t_id not in processed_ids:
                    duration = now_ts - entry_times[t_id]
                    if duration > 0:
                        speed = (REAL_DIST_M / duration) * 3.6
                        cursor.execute("""
                            INSERT INTO full_tracking_data 
                            (video_id, title, path, track_id, object_type, detection_time, x_cord_m, y_cord_m, speed_km_h) 
                            VALUES (12, 'main_analysis', %s, %s, %s, %s, %s, %s, %s)
                        """, (VIDEO_PATH, t_id, model.names[clss[i]], now_dt, float(cx), float(cy), float(speed)))
                        processed_ids.add(t_id)

            # --- ТРИГГЕР ОПАСНЫХ СБЛИЖЕНИЙ ---
            for i in range(len(active_objects)):
                for j in range(i + 1, len(active_objects)):
                    obj1, obj2 = active_objects[i], active_objects[j]
                    
                    # Евклидово расстояние в пикселях
                    dist_px = ((obj1['cx'] - obj2['cx'])**2 + (obj1['cy'] - obj2['cy'])**2)**0.5
                    dist_m = round(dist_px / PIXELS_PER_METER, 2)
                    
                    if dist_m < CRITICAL_DIST_M:
                        pair = tuple(sorted((obj1['id'], obj2['id'])))
                        
                        # Проверка кулдауна (чтобы не писать каждую долю секунды)
                        if pair not in last_incident_time or (now_ts - last_incident_time[pair]) > INCIDENT_COOLDOWN:
                            cursor.execute("""
                                INSERT INTO dangerous_incidents (time, track_id1, track_id2, distance) 
                                VALUES (%s, %s, %s, %s)
                            """, (now_dt, obj1['id'], obj2['id'], float(dist_m)))
                            
                            last_incident_time[pair] = now_ts
                            print(f"⚠️ Инцидент: ID {obj1['id']} и {obj2['id']} на расстоянии {dist_m}м")

        # Визуализация (для отладки можно уменьшить размер)
        cv2.imshow('Traffic Monitor', cv2.resize(annotated_frame, (960, 540)))
        if cv2.waitKey(1) & 0xFF == ord('q'): break

finally:
    cap.release()
    cv2.destroyAllWindows()
    cursor.close()
    conn.close()
# Out:
# 🚀 Система запущена. Детекция сближений активна.
# ⚠️ Инцидент: ID 8 и 80 на расстоянии 1.46м
# ⚠️ Инцидент: ID 5 и 95 на расстоянии 0.03м
# ⚠️ Инцидент: ID 4 и 141 на расстоянии 0.04м
# ⚠️ Инцидент: ID 9 и 147 на расстоянии 2.65м
# ⚠️ Инцидент: ID 34 и 197 на расстоянии 1.3м
# ⚠️ Инцидент: ID 272 и 199 на расстоянии 3.03м
# ⚠️ Инцидент: ID 272 и 291 на расстоянии 0.77м
# ⚠️ Инцидент: ID 49 и 332 на расстоянии 3.4м
# ⚠️ Инцидент: ID 49 и 332 на расстоянии 3.4м
# ⚠️ Инцидент: ID 49 и 332 на расстоянии 3.18м
# ⚠️ Инцидент: ID 361 и 376 на расстоянии 3.38м
# ⚠️ Инцидент: ID 3 и 412 на расстоянии 2.14м
# ⚠️ Инцидент: ID 379 и 3 на расстоянии 3.18м
# ⚠️ Инцидент: ID 412 и 3 на расстоянии 0.77м
# ⚠️ Инцидент: ID 424 и 428 на расстоянии 3.2м
# ⚠️ Инцидент: ID 361 и 435 на расстоянии 2.17м
# ⚠️ Инцидент: ID 367 и 437 на расстоянии 0.1м
# ⚠️ Инцидент: ID 449 и 503 на расстоянии 2.12м
# ⚠️ Инцидент: ID 515 и 269 на расстоянии 2.52м
# ⚠️ Инцидент: ID 449 и 527 на расстоянии 0.36м
# ⚠️ Инцидент: ID 449 и 534 на расстоянии 0.27м
# ⚠️ Инцидент: ID 449 и 539 на расстоянии 0.26м
# ⚠️ Инцидент: ID 1 и 545 на расстоянии 0.04м
# ⚠️ Инцидент: ID 493 и 225 на расстоянии 1.58м
# ⚠️ Инцидент: ID 225 и 570 на расстоянии 3.39м
# ⚠️ Инцидент: ID 454 и 3 на расстоянии 3.43м
# ⚠️ Инцидент: ID 578 и 585 на расстоянии 3.19м
# ⚠️ Инцидент: ID 583 и 435 на расстоянии 3.35м
# ⚠️ Инцидент: ID 454 и 592 на расстоянии 2.16м
# ⚠️ Инцидент: ID 3 и 592 на расстоянии 1.85м
# ⚠️ Инцидент: ID 225 и 591 на расстоянии 3.25м
# ⚠️ Инцидент: ID 3 и 610 на расстоянии 3.48м
# ⚠️ Инцидент: ID 435 и 623 на расстоянии 1.16м
# ⚠️ Инцидент: ID 449 и 629 на расстоянии 0.11м
# ⚠️ Инцидент: ID 690 и 720 на расстоянии 2.73м
# ⚠️ Инцидент: ID 533 и 726 на расстоянии 0.19м
# ⚠️ Инцидент: ID 533 и 729 на расстоянии 0.06м
# ⚠️ Инцидент: ID 712 и 731 на расстоянии 3.44м
# ⚠️ Инцидент: ID 225 и 744 на расстоянии 3.3м
# ⚠️ Инцидент: ID 668 и 744 на расстоянии 1.68м
# ⚠️ Инцидент: ID 570 и 749 на расстоянии 1.01м
# ⚠️ Инцидент: ID 570 и 768 на расстоянии 1.2м
# ⚠️ Инцидент: ID 570 и 796 на расстоянии 1.31м
# ⚠️ Инцидент: ID 862 и 868 на расстоянии 1.96м
# ⚠️ Инцидент: ID 862 и 875 на расстоянии 3.47м
# ⚠️ Инцидент: ID 862 и 875 на расстоянии 2.89м
# ⚠️ Инцидент: ID 805 и 875 на расстоянии 3.01м
# ⚠️ Инцидент: ID 805 и 935 на расстоянии 1.11м
# ⚠️ Инцидент: ID 937 и 919 на расстоянии 3.15м
# ⚠️ Инцидент: ID 856 и 938 на расстоянии 1.57м
# ⚠️ Инцидент: ID 862 и 902 на расстоянии 3.41м
# ⚠️ Инцидент: ID 991 и 1011 на расстоянии 2.73м
# ⚠️ Инцидент: ID 1006 и 1010 на расстоянии 1.24м
# ⚠️ Инцидент: ID 1006 и 1011 на расстоянии 2.83м
# ⚠️ Инцидент: ID 1010 и 1011 на расстоянии 1.6м
# ⚠️ Инцидент: ID 967 и 1019 на расстоянии 2.5м
# ⚠️ Инцидент: ID 991 и 1006 на расстоянии 3.34м
# ⚠️ Инцидент: ID 1036 и 1045 на расстоянии 3.06м
# ⚠️ Инцидент: ID 1036 и 1056 на расстоянии 1.0м
# ⚠️ Инцидент: ID 1036 и 1045 на расстоянии 2.13м
# ⚠️ Инцидент: ID 1056 и 1045 на расстоянии 1.16м
# ⚠️ Инцидент: ID 933 и 991 на расстоянии 2.98м
# ⚠️ Инцидент: ID 1036 и 1085 на расстоянии 3.07м
# ⚠️ Инцидент: ID 991 и 933 на расстоянии 1.61м
# ⚠️ Инцидент: ID 1006 и 1095 на расстоянии 2.01м
# ⚠️ Инцидент: ID 881 и 1113 на расстоянии 0.91м
# ⚠️ Инцидент: ID 881 и 1113 на расстоянии 0.73м
# ⚠️ Инцидент: ID 1095 и 1125 на расстоянии 1.89м
# ⚠️ Инцидент: ID 1036 и 1095 на расстоянии 3.41м
# ⚠️ Инцидент: ID 881 и 1113 на расстоянии 1.01м
# ⚠️ Инцидент: ID 1085 и 1128 на расстоянии 1.32м
# ⚠️ Инцидент: ID 881 и 1113 на расстоянии 0.96м
# ⚠️ Инцидент: ID 1147 и 1155 на расстоянии 0.32м
# ⚠️ Инцидент: ID 2763 и 3677 на расстоянии 2.69м
# ⚠️ Инцидент: ID 3561 и 3708 на расстоянии 0.16м
# ⚠️ Инцидент: ID 3637 и 3715 на расстоянии 1.68м
# ⚠️ Инцидент: ID 3722 и 3723 на расстоянии 1.55м
# ⚠️ Инцидент: ID 3665 и 3715 на расстоянии 3.48м
# ⚠️ Инцидент: ID 3742 и 3743 на расстоянии 2.19м
# ⚠️ Инцидент: ID 3665 и 3715 на расстоянии 2.81м
# ⚠️ Инцидент: ID 3740 и 3726 на расстоянии 1.06м
# ⚠️ Инцидент: ID 3726 и 3740 на расстоянии 1.35м
# ⚠️ Инцидент: ID 3756 и 3803 на расстоянии 2.02м
# ⚠️ Инцидент: ID 3751 и 3734 на расстоянии 3.37м
# ⚠️ Инцидент: ID 3833 и 3835 на расстоянии 0.01м
# ⚠️ Инцидент: ID 3862 и 3865 на расстоянии 2.81м
# ⚠️ Инцидент: ID 3862 и 3866 на расстоянии 2.71м
# ⚠️ Инцидент: ID 3953 и 3960 на расстоянии 1.31м
# ⚠️ Инцидент: ID 3953 и 3961 на расстоянии 1.75м
# ⚠️ Инцидент: ID 3960 и 3961 на расстоянии 2.93м
# ⚠️ Инцидент: ID 3960 и 3961 на расстоянии 3.08м
# ⚠️ Инцидент: ID 3979 и 3981 на расстоянии 3.38м

# %%
import requests # Не забудь добавить в начало файла

# Перед циклом while задаем таймер:
last_upload_time = time.time()
CLOUD_URL = "https://api.yourservice.com/upload" # Замени на URL из задания

while cap.isOpened():
    # ... тут идет чтение кадра и логика детекции (res = model.track...)
    
    now_ts = time.time()
    
    # === НОВЫЙ БЛОК: ОТПРАВКА В ОБЛАКО ===
    if now_ts - last_upload_time >= 30.0: # Прошло 30 секунд
        # Берем кадр с нарисованными рамками
        annotated_frame = res.plot() 
        
        # Кодируем кадр в формат JPEG в памяти (без сохранения на диск)
        _, buffer = cv2.imencode('.jpg', annotated_frame)
        
        try:
            # Отправляем POST запрос. Файл передается как multipart/form-data
            response = requests.post(
                CLOUD_URL, 
                files={"file": ("frame.jpg", buffer.tobytes(), "image/jpeg")},
                timeout=5 # Таймаут, чтобы видео не зависло, если облако тупит
            )
            print(f"Кадр отправлен в облако! Статус: {response.status_code}")
        except Exception as e:
            print(f"Ошибка отправки в облако: {e}")
            
        # Обновляем таймер
        last_upload_time = now_ts
    # ======================================
    # Облако S3
S3_ENDPOINT = "https://storage.yandexcloud.net"
S3_ACCESS_KEY = "ВАШ_КЛЮЧ"
S3_SECRET_KEY = "ВАШ_СЕКРЕТ"
S3_BUCKET_NAME = "traffic-frames-bucket"
# Скриншот в облако каждые 30 секунд
   if time.time() - last_upload_time >= 30:
        fname = f"frame_{now.strftime('%H%M%S')}.jpg"
        cv2.imwrite(fname, annotated_frame)
        try:
            s3_client.upload_file(fname, S3_BUCKET_NAME, f"records/{fname}")
            print(f"☁️ Кадр {fname} в S3")
        except: pass
        finally: 
            if os.path.exists(fname): os.remove(fname)
        last_upload_time = time.time()
