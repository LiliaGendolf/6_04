# %%
import pandas as pd
import psycopg2
import time
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score, mean_absolute_error
from datetime import datetime, timedelta
conn = psycopg2.connect("dbname=user43 user=user43 password=m5q3x8tpc7vn host=2.nntc.nnov.ru port=5402")
video_path = 'Модуль В/traffic_full_30min.csv'

# %%
DB_URL = "dbname=user43 user=user43 password=m5q3x8tpc7vn host=2.nntc.nnov.ru port=5402"
AVG_TIME_IN_FRAME = 5.0 # Среднее время нахождения авто в кадре (сек)

# 1. ПОДГОТОВКА И ОБУЧЕНИЕ
# Пересчитываем интенсивность из CSV в мгновенную плотность: Density = (Intensity / 3600) * TimeInFrame
df = pd.read_csv('Модуль В/traffic_full_30min.csv' )
df['instant_density'] = (df['intensity_30min'] / 1800.0) * AVG_TIME_IN_FRAME 
df['target'] = df['instant_density'].shift(-2) # Прогноз на +60 мин (2 шага по 30 мин)

train = df.dropna()
X, y = train[['instant_density']], train['target']

model = GradientBoostingRegressor(n_estimators=150, max_depth=5, random_state=42)
model.fit(X, y)

# Метрики
y_pred = model.predict(X)
print(f"📈 Точность модели (R2): {r2_score(y, y_pred):.3f}")
print(f"📉 Средняя ошибка (MAE): {mean_absolute_error(y, y_pred):.3f} машин")

# %%
# 2. ЦИКЛ ПРОГНОЗИРОВАНИЯ ДЛЯ ДАШБОРДА
print("🔁 Запуск цикла записи мгновенных прогнозов...")
try:
    while True:
        with psycopg2.connect(DB_URL) as conn:
            with conn.cursor() as cur:
                # Считаем, сколько машин в базе за последние 10 секунд (текущий срез)
                cur.execute("SELECT COUNT(DISTINCT track_id) FROM full_tracking_data WHERE detection_time >= NOW() - INTERVAL '10 second'")
                current_density = float(cur.fetchone()[0])
                
                # Предикт
                pred_density = float(model.predict([[current_density]])[0])
                pred_density = max(0, round(pred_density, 1)) # Округляем до 1 знака (напр. 1.5 машины)
                
                target_time = datetime.now() + timedelta(minutes=60)
                
                # Запись в таблицу прогнозов (обновляем значения для Дашборда)
                cur.execute("""
                    INSERT INTO traffic_predictions (target_time, horizon_minutes, predicted_intensity) 
                    VALUES (%s, 60, %s)
                """, (target_time, pred_density, current_density))
                
                print(f"[{datetime.now().strftime('%H:%M')}] Сейчас в кадре: {current_density} | Прогноз на +60 мин: {round(pred_density, 0)} ТС")
        
        time.sleep(30) # Обновляем прогноз каждые 30 секунд
except KeyboardInterrupt:
    print("Остановка модуля прогнозирования")

# %%
import pandas as pd
import psycopg2, time
from sklearn.ensemble import GradientBoostingRegressor
from datetime import datetime, timedelta

DB_URL = "dbname=user43 user=user43 password=m5q3x8tpc7vn host=2.nntc.nnov.ru port=5402"

# 1. Переобучаем модель на мгновенную плотность
df = pd.read_csv('traffic_full_30min.csv')
# Конвертируем интенсивность в среднее кол-во машин в кадре (плотность)
df['instant_count'] = (df['intensity_30min'] / 1800) * 4.0 
df['target'] = df['instant_count'].shift(-2) # Прогноз на +60 мин

train = df.dropna()
model = GradientBoostingRegressor(n_estimators=100).fit(train[['instant_count']], train['target'])

print("✅ ML-модель настроена на мгновенный прогноз плотности.")

# 2. Рабочий цикл для Дашборда
try:
    while True:
        with psycopg2.connect(DB_URL) as conn:
            with conn.cursor() as cur:
                # Считаем сколько машин в кадре прямо сейчас (за последние 5 сек)
                cur.execute("SELECT COUNT(DISTINCT track_id) FROM full_tracking_data WHERE detection_time >= NOW() - INTERVAL '5 second'")
                current_count = float(cur.fetchone()[0])
                
                # Делаем прогноз
                prediction = float(model.predict([[current_count]])[0])
                prediction = max(0, round(prediction, 1))
                
                target_time = datetime.now() + timedelta(minutes=60)
                
                # Пишем в базу для Дашборда
                # ВАЖНО: убедись, что в traffic_predictions колонки соответствуют (обычно это predicted_intensity)
                cur.execute("""
                    INSERT INTO traffic_predictions (target_time, horizon_minutes, predicted_intensity, predicted_avg_speed) 
                    VALUES (%s, 60, %s, %s)
                """, (target_time, prediction, current_count))
                
                print(f"[{datetime.now().strftime('%H:%M')}] Сейчас машин: {current_count} | Прогноз через час: {prediction}")
        
        time.sleep(30)
except KeyboardInterrupt:
    print("Прогноз остановлен.")

# %%
import pandas as pd
import psycopg2, time
from sklearn.ensemble import GradientBoostingRegressor
from datetime import datetime, timedelta

DB_URL = "dbname=user43 user=user43 password=m5q3x8tpc7vn host=2.nntc.nnov.ru port=5402"

# 1. Переобучаем модель на мгновенную плотность
df = pd.read_csv('Модуль В/traffic_full_30min.csv')
# Конвертируем интенсивность в среднее кол-во машин в кадре (плотность)
df['instant_count'] = (df['intensity_30min'] / 1800) * 4.0 
df['target'] = df['instant_count'].shift(-2) # Прогноз на +60 мин

train = df.dropna()
model = GradientBoostingRegressor(n_estimators=100).fit(train[['instant_count']], train['target'])

print("✅ ML-модель настроена на мгновенный прогноз плотности.")

# 2. Рабочий цикл для Дашборда
try:
    while True:
        with psycopg2.connect(DB_URL) as conn:
            with conn.cursor() as cur:
                # Считаем сколько машин в кадре прямо сейчас (за последние 5 сек)
                cur.execute("SELECT COUNT(DISTINCT track_id) FROM full_tracking_data WHERE detection_time >= NOW() - INTERVAL '5 second'")
                current_count = float(cur.fetchone()[0])
                
                # Делаем прогноз
                prediction = float(model.predict([[current_count]])[0])
                prediction = max(0, round(prediction, 1))
                
                target_time = datetime.now() + timedelta(minutes=60)
                
                # Пишем в базу для Дашборда
                # ВАЖНО: убедись, что в traffic_predictions колонки соответствуют (обычно это predicted_intensity)
                cur.execute("""
                    INSERT INTO traffic_predictions (target_time, horizon_minutes, predicted_intensity, predicted_avg_speed) 
                    VALUES (%s, 60, %s, %s)
                """, (target_time, prediction, current_count))
                
                print(f"[{datetime.now().strftime('%H:%M')}] Сейчас машин: {current_count} | Прогноз через час: {prediction}")
        
        time.sleep(30)
except KeyboardInterrupt:
    print("Прогноз остановлен.")

# %%
import pandas as pd
import numpy as np
import psycopg2
import time
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from datetime import datetime, timedelta

# --- КОНФИГУРАЦИЯ ---
DB_URL = "dbname=user43 user=user43 password=m5q3x8tpc7vn host=2.nntc.nnov.ru port=5402"
CSV_PATH = 'Модуль В/traffic_full_30min.csv'
HORIZON = 60 # Фиксированный горизонт по КЗ (60 минут)

print("⚙️ Шаг 1: Обучение модели и оценка точности...")

# 1. Загрузка и подготовка данных
try:
    df = pd.read_csv(CSV_PATH)
    # Приводим к минутной интенсивности
    df['moment_cars'] = df['intensity_30min'] / 30.0 
    # Сдвиг таргета на 60 минут (предполагаем, что шаг в CSV - 30 минут, значит сдвиг на 2 строки)
    df['target'] = df['moment_cars'].shift(-2) 
    
    valid_data = df.dropna()
    X = valid_data[['moment_cars']]
    y = valid_data['target']
    
    # Обучение модели
    model = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=4, random_state=42)
    model.fit(X, y)
    
    # Оценка точности
    preds = model.predict(X)
    mae = mean_absolute_error(y, preds)
    rmse = mean_squared_error(y, preds) ** 0.5
    r2 = r2_score(y, preds)
    
    print("-" * 40)
    print(f"✅ Модель обучена. Горизонт: +{HORIZON} мин")
    print("МЕТРИКИ КАЧЕСТВА:")
    print("MAE:  {0:7.2f}".format(mae))
    print("RMSE: {0:7.2f}".format(rmse))
    print("R2:   {0:7.2f}".format(r2))
    print("-" * 40)
    
except Exception as e:
    print(f"❌ Ошибка при обучении: {e}")
    exit()

# 2. Рабочий цикл прогнозирования
print("🚀 Шаг 2: Запуск бесконечного цикла прогнозирования (каждые 30 сек)...")

def predict_and_store():
    try:
        with psycopg2.connect(DB_URL) as conn:
            with conn.cursor() as cur:
                # Берем реальный факт за последние 5 минут для сглаживания
                cur.execute("""
                    SELECT COUNT(DISTINCT track_id), COALESCE(AVG(speed_km_h), 0) 
                    FROM full_tracking_data 
                    WHERE detection_time >= NOW() - INTERVAL '5 minute'
                """)
                row = cur.fetchone()
                
                # Защита от пустых ответов
                curr_count = float(row[0]) if row[0] is not None else 0.0
                curr_speed = float(row[1]) if row[1] is not None else 0.0
                
                now = datetime.now()
                target_time = now + timedelta(minutes=HORIZON)
                
                # Создаем DataFrame для предикта, чтобы не было Warning'ов
                input_df = pd.DataFrame([[curr_count]], columns=['moment_cars'])
                pred_val = float(model.predict(input_df)[0])
                pred_val = max(0.0, pred_val) # Интенсивность не может быть отрицательной
                
                # Вставка в БД
                cur.execute("""
                    INSERT INTO traffic_predictions 
                    (target_time, horizon_minutes, predicted_intensity, predicted_avg_speed) 
                    VALUES (%s, %s, %s, %s)
                """, (target_time, HORIZON, pred_val, curr_speed))
                
                print(f"[{now.strftime('%H:%M:%S')}] 🔮 Прогноз записан | Факт сейчас: {int(curr_count)} ТС | Прогноз через {HORIZON}м: {pred_val:.1f} ТС")
                
    except Exception as e:
        print(f"❌ Ошибка БД в цикле прогноза: {e}")

# Бесконечный цикл с обработкой прерывания
try:
    while True:
        predict_and_store()
        time.sleep(30) # Запуск по расписанию (раз в 30 секунд для демо)
except KeyboardInterrupt:
    print("\n🛑 Цикл прогнозирования остановлен пользователем.")
